# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''4
1
2
1
3
3
102
4
2069
''')

# %%
from sys import stdin, stdout

class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1

    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))

    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self

    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

class Problem:
    def __init__(self):
        self.oo = float("inf")
    
    def gcd(self, a, b):
        return a if b == 0 else self.gcd(b, a % b)
    
    def modpow(self, a, n, m):
        ans = 1

        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m

        return ans

    '''
    A. Digit Game
    '''
    def solve(self, n, digits):
        odd = [0, 0]
        even = [0, 0]

        for i in range(len(digits)):
            d = int(digits[i])
            if i % 2 == 0:
                odd[d % 2] += 1
            else:
                even[d % 2] += 1
            
        if n % 2 == 0:
            print(2 if even[0] else 1)
        else:
            print(1 if odd[1] else 2)

try:
    p = Problem()
    for tc in Input().known_tests():
        p.solve(*tc.array(), tc.line())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 2
# 1
# 1
# 2

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''4
1
8
6
1000000000000000000
''')

# %%
from sys import stdin, stdout

class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1

    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))

    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self

    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

class Problem:
    def __init__(self):
        self.oo = float("inf")
    
    def gcd(self, a, b):
        return a if b == 0 else self.gcd(b, a % b)
    
    def modpow(self, a, n, m):
        ans = 1

        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m

        return ans

    '''
    B. Stairs
    '''
    def solve(self, n):
        ans = 0

        s = 1
        c = 1
        while n >= c:
            ans += 1
            n -= c

            c *= 2
            s *= 2
            c += s * s

        print(ans)

try:
    p = Problem()
    for tc in Input().known_tests():
        p.solve(*tc.array())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 1
# 2
# 1
# 30

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''3
2 69
68 70
6 4
4 4 4 4 4 4
9 38
-21 83 50 -59 -77 15 -71 -78 20
''')

# %%
from sys import stdin, stdout

class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1

    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))

    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self

    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

class Problem:
    def __init__(self):
        self.oo = float("inf")
    
    def gcd(self, a, b):
        return a if b == 0 else self.gcd(b, a % b)
    
    def modpow(self, a, n, m):
        ans = 1

        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m

        return ans

    '''
    C. Killjoy
    '''
    def solve(self, n, x, a):
        infected = 0
        for c in a:
            if c == x:
                infected += 1

        remain = n - infected

        if remain == 0:
            print(0)
        elif infected > 0:
            print(1)
        else:
            r = 0
            for c in a:
                r += x - c

            if r == 0:
                print(1)
            else:
                print(2)

try:
    p = Problem()
    for tc in Input().known_tests():
        p.solve(*tc.array(), tc.array())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 1
# 0
# 2

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''5
1 2 3 4 5
''')

# %%
from sys import stdin, stdout

class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1

    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))

    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self

    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

class Problem:
    def __init__(self):
        self.oo = float("inf")
    
    def gcd(self, a, b):
        return a if b == 0 else self.gcd(b, a % b)
    
    def modpow(self, a, n, m):
        ans = 1

        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m

        return ans

    '''
    D1. Sage's Birthday (easy version)
    '''
    def solve(self, n, a):
        a.sort(reverse = True)
        
        i = 1
        count = 0
        while i + 1 < n:
            count += 1
            a[i], a[i + 1] = a[i + 1], a [i]
            i += 2

        print(count)
        print(*a)

try:
    p = Problem()
    for tc in Input().unknown_tests():
        p.solve(*tc.array(), tc.array())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 2
# 5 3 4 1 2

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''5
1 2 3 4 5
7
1 3 2 2 4 5 4
1
1
2
1 1
2
1 2
9
1 1 1 1 2 2 3 3 3
5
1 2 2 2 2
4
2 2 2 1
''')

# %%
from sys import stdin, stdout
    
class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1
    
    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))
    
    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self
    
    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self
    
class Problem:
    def __init__(self):
        self.oo = float("inf")
    
    def gcd(self, a, b):
        return a if b == 0 else self.gcd(b, a % b)
    
    def modpow(self, a, n, m):
        ans = 1
    
        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m
    
        return ans
    
    '''
    D2. Sage's Birthday (hard version)
    '''
    def solve(self, n, a):
        a.sort(reverse = True)
        b = [0 for i in range(n)]
    
        i = 0
        j = 0
        while j < n:
            b[j] = a[i]
            i += 1
            j += 2
        
        k = i
        while k < n and a[k] == a[0]:
            k += 1
        j = 1
        count = 0
        l = k
        while l < n:
            b[j] = a[l]
            if (j + 1 < n) and (b[j - 1] > b[j]) and (b[j + 1] > b[j]):
                count += 1

            l += 1
            j += 2
        
        while i < k:
            b[j] = a[i]
            i += 1
            j += 2
    
        print(count)
        print(*b)

try:
    p = Problem()
    for tc in Input().unknown_tests():
        p.solve(*tc.array(), tc.array())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 2
# 5 2 4 1 3
# 3
# 5 2 4 2 4 1 3
# 0
# 1
# 0
# 1 1
# 0
# 2 1
# 4
# 3 1 3 1 3 1 2 1 2
# 1
# 2 1 2 2 2
# 1
# 2 1 2 2

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''5
6
4
30
12
90518849
''')

# %%
from sys import stdin, stdout
    
class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1
    
    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))
    
    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self
    
    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

def problem_solver():
    oo = float("inf")
    
    def gcd(a, b):
        return a if b == 0 else gcd(b, a % b)
    
    def modpow(a, n, m):
        ans = 1
    
        while n:
            if n & 1:
                ans = (ans * a) % m
            n >>= 1
            a = (a * a) % m
    
        return ans

    prime_numbers = []
    def primes():
        for p in prime_numbers:
            yield p

        q = prime_numbers[-1] + 1 if len(prime_numbers) else 2
        while True:
            is_prime = True
            for p in prime_numbers:
                if q % p == 0:
                    is_prime = False
                    break
            
            if is_prime:
                prime_numbers.append(q)
                yield q
            
            q += 1

    def prime_factors(n):
        factors = []

        for p in primes():
            if p * p > n:
                break
                
            if n % p != 0:
                continue

            r = 0
            while n % p == 0:
                r += 1
                n //= p

            factors.append((p, r))
        
        if n > 1:
            factors.append((n, 1))

        return factors

    '''
    E. Decryption
    '''
    def solver(n):
        f = prime_factors(n)

        divs = [1]
        e = [0, 1]
        for p, r in f:
            q = 1
            for i in range(r):
                q *= p
                for d in divs[:e[-1]]:
                    divs.append(q * d)
            e.append(len(divs))

        for i in range(1, len(e)):
            le = e[i - 1]
            ri = e[i]
            divs[le:ri] = divs[le:ri][::-1]

        if len(divs) > 1:
            divs[-1], divs[-2] = divs[-2], divs[-1]

        print(*divs[1:])
        count = 0
        if len(f) == 2 and len(divs) == 4:
            count = 1
        print(count)

    return solver

try:
    solver = problem_solver()
    for tc in Input().known_tests():
        solver(*tc.array())
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 2 3 6
# 1
# 2 4
# 0
# 2 6 3 30 15 5 10
# 0
# 4 2 12 3 6
# 0
# 90518849 449 201601
# 0

# %%
from io import StringIO
import sys

sys.stdin = StringIO(
'''4
100 0
0 100
-100 0
0 -100
7
0 2
1 0
-3 0
0 -2
-1 -1
-1 -3
-2 -3
5
0 0
0 -1
3 0
-2 0
-2 1
5
0 0
2 0
0 -1
-2 0
-2 1
''')

# %%
from sys import stdin, stdout
    
class Input:
    def __init__(self):
        self.lines = stdin.read().splitlines()
        self.idx = 0
    
    def line(self):
        try:
            return self.lines[self.idx]
        finally:
            self.idx += 1
    
    def array(self, sep = ' ', cast = int):
        return list(map(cast, self.line().split(sep = sep)))
    
    def known_tests(self):
        num_of_cases, = self.array()
    
        for case in range(num_of_cases):
            yield self
    
    def unknown_tests(self):
        while self.idx < len(self.lines):
            yield self

def problem_solver():
    

    '''
    '''
    def solver(inpt):
        X = 0
        Y = 1
        n, = inpt.array()
        dtch = [inpt.array() for i in range(n)]
        dtch.sort()

        xcrd = {}
        ycrd = {}
        for i in range(n):
            x = dtch[i][X]
            y = dtch[i][Y]

            if not x in xcrd:
                xcrd[x] = []
            if not y in ycrd:
                ycrd[y] = []
            
            xcrd[x].append(i)
            ycrd[y].append(i)
        
        edg = []
        for x, d in xcrd.items():
            for i in range(1, len(d)):
                u = d[i-1]
                v = d[i]
                edg.append((u, v, dtch[v][Y] - dtch[u][Y]))
        
        for y, d in ycrd.items():
            for i in range(1, len(d)):
                u = d[i-1]
                v = d[i]
                edg.append((u, v, dtch[v][X] - dtch[u][X]))

        print(n, edg)

    return solver

try:
    solver = problem_solver()
    for tc in Input().unknown_tests():
        solver(tc)
except Exception as e:
    import traceback
    traceback.print_exc(file=stdout)
# Out:
# 4 [(1, 2, 200), (0, 3, 200)]
# 7 [(2, 3, 2), (4, 5, 4), (0, 6, 4), (1, 2, 1)]
# 5 [(0, 1, 1), (2, 3, 1), (0, 3, 2), (3, 4, 3)]
# 5 [(0, 1, 1), (2, 3, 1), (0, 3, 2), (3, 4, 2)]
